# %%
#https://comma.ai
#https://github.com/commaai/openpilot
#https://en.wikipedia.org/wiki/Adaptive_cruise_control

#clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15283, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 15283 (delta 39), reused 51 (delta 26), pack-reused 15186
# Receiving objects: 100% (15283/15283), 13.78 MiB | 16.84 MiB/s, done.
# Resolving deltas: 100% (10350/10350), done.

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
#change makefile to have OPENCV, GPU, CUDNN enabled
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
#compile Darknet
# !make

# %%
#get yolov3 pretrained coco dataset weights
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import IPython
import time
import math

# %%
min_confidence = 0.5

weight_file = 'yolov3.weights'
cfg_file = 'cfg/yolov3.cfg'
name_file = 'data/coco.names'

#https://bdd-data.berkeley.edu/ 에서 dataset download
#http://dl.yf.io/bdd100k/video_parts/bdd100k_videos_test_00.zip의 첫번째 video file
file_name = 'cabc30fc-e7726578.mp4'

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6253c140-89da-46af-913b-8f2813d3d4dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6253c140-89da-46af-913b-8f2813d3d4dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cabc30fc-e7726578.mp4 to cabc30fc-e7726578.mp4

# %%
#load yolo
net = cv2.dnn.readNet(weight_file, cfg_file)

# %%
classes = []
with open(name_file, 'r') as f:
  classes = [line.strip() for line in f.readlines()]
print(classes)
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0]-1] for i in net.getUnconnectedOutLayers()]
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0]-1] for i in net.getUnconnectedOutLayers()]

# %%
def writeFrame(img):
  #use global variable, writer
  global writer
  height, width  = img.shape[:2]
  if writer is None and output_name is not None:
    fourcc = cv2.VideoWriter_fourcc(*"MJPG")
    writer = cv2.VideoWriter(output_name, fourcc, 24, (width, height), True)
  if writer is not None:
    writer.write(img)

# %%
trackerTypes = ['BOOSTING', 'MIL', 'KCF','TLD', 'MEDIANFLOW', 'GOTURN', 'MOSSE', 'CSRT']

def createTrackerByName(trackerType):
  # Create a tracker based on tracker name
  if trackerType == trackerTypes[0]:
    tracker = cv2.TrackerBoosting_create()
  elif trackerType == trackerTypes[1]:
    tracker = cv2.TrackerMIL_create()
  elif trackerType == trackerTypes[2]:
    tracker = cv2.TrackerKCF_create()
  elif trackerType == trackerTypes[3]:
    tracker = cv2.TrackerTLD_create()
  elif trackerType == trackerTypes[4]:
    tracker = cv2.TrackerMedianFlow_create()
  elif trackerType == trackerTypes[5]:
    tracker = cv2.TrackerGOTURN_create()
  elif trackerType == trackerTypes[6]:
    tracker = cv2.TrackerMOSSE_create()
  elif trackerType == trackerTypes[7]:
    tracker = cv2.TrackerCSRT_create()
  else:
    tracker = None
    print('Incorrect tracker name')
    print('Available trackers are:')
    for t in trackerTypes:
      print(t)
  return tracker

# %%
frame_count = 0

#initialize the video writer
writer = None
output_name = 'output_video.avi'

file_name = 'cabc30fc-e7726578.mp4'
face_cascade_name = 'haarcascade_frontalface_alt.xml'

detected = False
frame_mode = 'Tracking'
elapsed_time = 0

trackers = cv2.MultiTracker_create()


# csrt
#tracker = cv2.TrackerCSRT_create()
# kcf
#tracker = cv2.TrackerKCF_create()
#boostring
#tracker = cv2.TrackerBoosting_create()
#mil
#tracker = cv2.TrackerMIL_create()
#tld
#tracker = cv2.TrackerTLD_create()
#medianflow
#tracker = cv2.TrackerMedianFlow_create()
#mosse
#tracker = cv2.TrackerMOSSE_create()

tracker = createTrackerByName(trackerTypes[2])

detected_width = 0
margin = 70


vs = cv2.VideoCapture(file_name)
while True:
  start_time = time.time()
  frame_count += 1
  
  ret, frame = vs.read()
  if frame is None:
    print('no more frame')
    break
  
  IPython.display.clear_output(wait=True)
  height, width, channels = frame.shape
  
  class_ids = []
  confidences = []
  boxes = []

  #region of interest
  roi_left = int(0.3*width)
  roi_right = int(0.6*width)

  if detected:
    frame_mode = 'Tracking'
    (success, tracking_boxes) = trackers.update(frame)
    for box in boxes:
      (x, y, w, h) = [int(v) for v in box]
      cv2.rectangle(frame, (x,y), (x+w, y+h), (0, 255,0), 2)

    tracking_box = tracking_boxes[0]
    tx = int(tracking_box[0])
    ty = int(tracking_box[1])
    tw = int(tracking_box[2])
    th = int(tracking_box[3])

    roi = frame[ty-margin:ty+th+margin, tx-margin:tx+tw+margin]
    
    roi_width, roi_height = roi.shape[:2]

    blob = cv2.dnn.blobFromImage(roi, 0.00392, (416,416), (0,0,0), True, crop=False)

    net.setInput(blob)
    outs = net.forward(output_layers)

    for out in outs:
      for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if (confidence > min_confidence) and (class_id == 2):
          #object detected
          center_x = int(detection[0] * roi_width)
          center_y = int(detection[1] * roi_height)
          w = int(detection[2] * roi_height)
          h = int(detection[3] * roi_height)

          #ractangle coordinates
          x = int(center_x - w / 2)
          y = int(center_y - h / 2)
          boxes.append([x,y,w,h])
    if len(boxes):
      boxes.sort(key=lambda x: x[2], reverse=True)
      box = boxes[0]
      x = box[0]
      y = box[1]
      w = box[2]
      h = box[3]
      roi_x = tx-margin + x    
      roi_y = ty-margin + y
      distance_width = w - detected_width

      cv2.rectangle(frame, (roi_x, roi_y), (roi_x+w, roi_y+h), (0, 255,255),1)
      label = 'Initial width: ' + str(detected_width) + ', current width: ' + str(w) + ', distance: ' + str(w-distance_width)
      print(box, label)
      if abs(distance_width) > 5:
        if distance_width < 0:
          cv2.putText(frame, 'speed up', (30,100), cv2.FONT_HERSHEY_COMPLEX, 2, (255,0,0), 5)
        elif distance_width < 30:
          cv2.putText(frame, 'slow down', (30,100), cv2.FONT_HERSHEY_COMPLEX, 2, (0,128,128), 5)
        else:
          cv2.putText(frame, 'be careful', (30,100), cv2.FONT_HERSHEY_COMPLEX, 2, (0,0,255), 5)
      cv2.putText(frame, label, (30, 30), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 255,0), 1)
    cv2.rectangle(frame, (tx, ty), (tx+w, ty+h), (255,255,0), 1)
    cv2.rectangle(frame, (tx-margin, ty-margin), (tx+tw+margin, ty+th+margin), (255,0,0), 1)
  else:
    frame_mode = 'Detection'
    
    height, width, channels = frame.shape

    blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0,0,0), True, crop=False)

    net.setInput(blob)
    outs = net.forward(output_layers)
    
    
    for out in outs:
      for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]

        #filter only car
        if (confidence > min_confidence) and class_id == 2:
          #object detected
          center_x = int(detection[0]*width)
          center_y = int(detection[1]*height)
          w = int(detection[2]*width)
          h = int(detection[3]*height)

          #rectangle coordinates
          x = int(center_x - w / 2)
          y = int(center_y - h / 2)

          boxes.append([x, y, w, h])
          confidences.append(float(confidence))
          class_ids.append(class_id)

    #Region of interest

    roi_left = int(0.3 * width)
    roi_right = int(0.6 * width)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, min_confidence, 0.4)
    font = cv2.FONT_HERSHEY_COMPLEX

    for i in range(len(boxes)):
      if i in indexes:
        x, y, w, h = boxes[i]
        
        #eliminate small object( < 50 )
        if ( w > 50 ) and ( x > roi_left and x < roi_right):
          label = str(classes[class_ids[i]])
          print(class_ids[i], label, w)
          color = (0, 255, 0)
          selected = boxes[i]
          detected_width = w
          cv2.rectangle(frame, (x,y), (x+w, y+h), color, 2)
    
    trackers.add(tracker, frame, tuple(selected))
    detected = True

    cv2_imshow(frame)
    frame_time = time.time() - start_time
    elapsed_time += frame_time
    print("[{}] Frame {} time {}".format(frame_mode, frame_count, frame_time))

    writeFrame(frame)
  
print("elapsed time {}".format(elapsed_time))
vs.release()
# Out:
# [50, 83, 85, 64] Initial width: 96, current width: 85, distance: 96
# [51, 83, 84, 65] Initial width: 96, current width: 84, distance: 96
# [52, 84, 84, 64] Initial width: 96, current width: 84, distance: 96
# [49, 82, 85, 64] Initial width: 96, current width: 85, distance: 96
# [50, 78, 88, 75] Initial width: 96, current width: 88, distance: 96
# [50, 78, 87, 76] Initial width: 96, current width: 87, distance: 96
# [49, 78, 88, 75] Initial width: 96, current width: 88, distance: 96
# [49, 78, 88, 78] Initial width: 96, current width: 88, distance: 96
# [49, 79, 88, 78] Initial width: 96, current width: 88, distance: 96
# [48, 77, 88, 77] Initial width: 96, current width: 88, distance: 96
# [47, 80, 89, 75] Initial width: 96, current width: 89, distance: 96
# [48, 78, 92, 76] Initial width: 96, current width: 92, distance: 96
# [48, 78, 90, 78] Initial width: 96, current width: 90, distance: 96
# [48, 78, 90, 78] Initial width: 96, current width: 90, distance: 96
# [47, 78, 91, 77] Initial width: 96, current width: 91, distance: 96
# [48, 76, 88, 79] Initial width: 96, current width: 88, distance: 96
# [48, 77, 90, 80] Initial width: 96, current width: 90, distance: 96
# [49, 78, 92, 77] Initial width: 96, current width: 92, distance: 96
# [46, 78, 91, 77] Initial width: 96, current width: 91, distance: 96
# [48, 77, 89, 78] Initial width: 96, current width: 89, distance: 96
# [46, 79, 93, 80] Initial width: 96, current width: 93, distance: 96
# [45, 78, 93, 77] Initial width: 96, current width: 93, distance: 96
# [46, 78, 92, 78] Initial width: 96, current width: 92, distance: 96
# [45, 78, 94, 82] Initial width: 96, current width: 94, distance: 96
# [46, 77, 95, 81] Initial width: 96, current width: 95, distance: 96
# [46, 77, 95, 80] Initial width: 96, current width: 95, distance: 96
# [46, 78, 94, 82] Initial width: 96, current width: 94, distance: 96
# [45, 77, 93, 80] Initial width: 96, current width: 93, distance: 96
# [45, 78, 94, 80] Initial width: 96, current width: 94, distance: 96
# [45, 77, 93, 80] Initial width: 96, current width: 93, distance: 96
# [44, 75, 95, 86] Initial width: 96, current width: 95, distance: 96
# [45, 75, 93, 83] Initial width: 96, current width: 93, distance: 96
# [44, 76, 93, 83] Initial width: 96, current width: 93, distance: 96
# [45, 76, 93, 82] Initial width: 96, current width: 93, distance: 96
# [45, 76, 93, 82] Initial width: 96, current width: 93, distance: 96
# [45, 75, 94, 86] Initial width: 96, current width: 94, distance: 96
# [43, 77, 95, 81] Initial width: 96, current width: 95, distance: 96
# [45, 75, 94, 84] Initial width: 96, current width: 94, distance: 96
# [44, 73, 93, 85] Initial width: 96, current width: 93, distance: 96
# [41, 73, 97, 87] Initial width: 96, current width: 97, distance: 96
# [39, 74, 99, 85] Initial width: 96, current width: 99, distance: 96
# [44, 72, 96, 87] Initial width: 96, current width: 96, distance: 96
# [40, 73, 100, 89] Initial width: 96, current width: 100, distance: 96
# [40, 75, 100, 86] Initial width: 96, current width: 100, distance: 96
# [39, 76, 101, 86] Initial width: 96, current width: 101, distance: 96
# [41, 73, 98, 87] Initial width: 96, current width: 98, distance: 96
# [41, 75, 99, 85] Initial width: 96, current width: 99, distance: 96
# [41, 74, 100, 89] Initial width: 96, current width: 100, distance: 96
# [40, 75, 101, 88] Initial width: 96, current width: 101, distance: 96
# [41, 74, 97, 86] Initial width: 96, current width: 97, distance: 96
# [41, 75, 101, 86] Initial width: 96, current width: 101, distance: 96
# [40, 74, 101, 88] Initial width: 96, current width: 101, distance: 96
# [38, 72, 103, 91] Initial width: 96, current width: 103, distance: 96
# [40, 73, 101, 91] Initial width: 96, current width: 101, distance: 96
# [39, 72, 102, 94] Initial width: 96, current width: 102, distance: 96
# [36, 73, 105, 92] Initial width: 96, current width: 105, distance: 96
# [37, 72, 103, 93] Initial width: 96, current width: 103, distance: 96
# [38, 71, 103, 93] Initial width: 96, current width: 103, distance: 96
# [39, 73, 103, 94] Initial width: 96, current width: 103, distance: 96
# [39, 72, 104, 92] Initial width: 96, current width: 104, distance: 96
# [40, 72, 103, 96] Initial width: 96, current width: 103, distance: 96
# [37, 69, 104, 96] Initial width: 96, current width: 104, distance: 96
# [37, 71, 105, 94] Initial width: 96, current width: 105, distance: 96
# [39, 72, 104, 92] Initial width: 96, current width: 104, distance: 96
# [37, 72, 105, 93] Initial width: 96, current width: 105, distance: 96
# [38, 72, 105, 94] Initial width: 96, current width: 105, distance: 96
# [39, 71, 104, 93] Initial width: 96, current width: 104, distance: 96
# [38, 69, 103, 96] Initial width: 96, current width: 103, distance: 96
# [39, 70, 104, 95] Initial width: 96, current width: 104, distance: 96
# [39, 69, 103, 97] Initial width: 96, current width: 103, distance: 96
# [39, 69, 104, 98] Initial width: 96, current width: 104, distance: 96
# [38, 68, 105, 99] Initial width: 96, current width: 105, distance: 96
# [39, 68, 104, 99] Initial width: 96, current width: 104, distance: 96
# [36, 70, 110, 96] Initial width: 96, current width: 110, distance: 96
# [36, 68, 108, 103] Initial width: 96, current width: 108, distance: 96
# [34, 68, 109, 97] Initial width: 96, current width: 109, distance: 96
# [37, 67, 107, 102] Initial width: 96, current width: 107, distance: 96
# [33, 66, 111, 102] Initial width: 96, current width: 111, distance: 96
# [31, 67, 111, 102] Initial width: 96, current width: 111, distance: 96
# [33, 65, 111, 103] Initial width: 96, current width: 111, distance: 96
# [31, 66, 111, 105] Initial width: 96, current width: 111, distance: 96
# [30, 67, 112, 104] Initial width: 96, current width: 112, distance: 96
# [32, 67, 110, 105] Initial width: 96, current width: 110, distance: 96
# [30, 66, 114, 105] Initial width: 96, current width: 114, distance: 96
# [29, 67, 115, 105] Initial width: 96, current width: 115, distance: 96
# [31, 66, 114, 105] Initial width: 96, current width: 114, distance: 96
# [29, 66, 113, 106] Initial width: 96, current width: 113, distance: 96
# [30, 66, 114, 105] Initial width: 96, current width: 114, distance: 96
# [30, 77, 114, 102] Initial width: 96, current width: 114, distance: 96
# [29, 67, 114, 108] Initial width: 96, current width: 114, distance: 96
# [20, 68, 119, 104] Initial width: 96, current width: 119, distance: 96
# [23, 68, 114, 105] Initial width: 96, current width: 114, distance: 96
# [21, 70, 118, 102] Initial width: 96, current width: 118, distance: 96
# [18, 67, 122, 105] Initial width: 96, current width: 122, distance: 96
# [28, 68, 116, 105] Initial width: 96, current width: 116, distance: 96
# [24, 75, 117, 105] Initial width: 96, current width: 117, distance: 96
# [27, 67, 118, 108] Initial width: 96, current width: 118, distance: 96
# [22, 74, 119, 107] Initial width: 96, current width: 119, distance: 96
# [22, 68, 117, 107] Initial width: 96, current width: 117, distance: 96
# [28, 67, 117, 106] Initial width: 96, current width: 117, distance: 96
# [29, 67, 115, 105] Initial width: 96, current width: 115, distance: 96
# [31, 57, 114, 99] Initial width: 96, current width: 114, distance: 96
# [26, 68, 119, 105] Initial width: 96, current width: 119, distance: 96
# [26, 78, 121, 100] Initial width: 96, current width: 121, distance: 96
# [24, 68, 118, 107] Initial width: 96, current width: 118, distance: 96
# [24, 67, 118, 110] Initial width: 96, current width: 118, distance: 96
# [22, 65, 127, 115] Initial width: 96, current width: 127, distance: 96
# [27, 66, 120, 112] Initial width: 96, current width: 120, distance: 96
# [20, 65, 123, 113] Initial width: 96, current width: 123, distance: 96
# [21, 60, 124, 119] Initial width: 96, current width: 124, distance: 96
# [24, 64, 124, 117] Initial width: 96, current width: 124, distance: 96
# [20, 61, 122, 119] Initial width: 96, current width: 122, distance: 96
# [14, 66, 131, 112] Initial width: 96, current width: 131, distance: 96
# [17, 66, 125, 111] Initial width: 96, current width: 125, distance: 96
# [18, 65, 126, 113] Initial width: 96, current width: 126, distance: 96
# [22, 63, 127, 116] Initial width: 96, current width: 127, distance: 96
# [21, 65, 129, 116] Initial width: 96, current width: 129, distance: 96
# [20, 63, 131, 117] Initial width: 96, current width: 131, distance: 96
# [19, 65, 124, 115] Initial width: 96, current width: 124, distance: 96
# [19, 65, 124, 115] Initial width: 96, current width: 124, distance: 96
# [19, 65, 125, 116] Initial width: 96, current width: 125, distance: 96
# [17, 63, 127, 120] Initial width: 96, current width: 127, distance: 96
# [18, 66, 126, 116] Initial width: 96, current width: 126, distance: 96
# [20, 64, 124, 118] Initial width: 96, current width: 124, distance: 96
# [18, 64, 125, 115] Initial width: 96, current width: 125, distance: 96
# [14, 65, 133, 115] Initial width: 96, current width: 133, distance: 96
# [15, 64, 131, 118] Initial width: 96, current width: 131, distance: 96
# [12, 64, 134, 118] Initial width: 96, current width: 134, distance: 96
# [16, 63, 140, 119] Initial width: 96, current width: 140, distance: 96
# [14, 63, 143, 119] Initial width: 96, current width: 143, distance: 96
# [10, 64, 137, 118] Initial width: 96, current width: 137, distance: 96
# [10, 63, 136, 117] Initial width: 96, current width: 136, distance: 96
# [14, 63, 144, 120] Initial width: 96, current width: 144, distance: 96
# [9, 62, 138, 121] Initial width: 96, current width: 138, distance: 96
# [15, 60, 141, 125] Initial width: 96, current width: 141, distance: 96
# [15, 61, 142, 123] Initial width: 96, current width: 142, distance: 96
# [13, 60, 145, 123] Initial width: 96, current width: 145, distance: 96
# [10, 62, 136, 123] Initial width: 96, current width: 136, distance: 96
# [12, 63, 133, 122] Initial width: 96, current width: 133, distance: 96
# [13, 60, 146, 124] Initial width: 96, current width: 146, distance: 96
# [7, 64, 139, 119] Initial width: 96, current width: 139, distance: 96
# [6, 64, 143, 118] Initial width: 96, current width: 143, distance: 96
# [6, 64, 143, 119] Initial width: 96, current width: 143, distance: 96
# [1, 63, 150, 119] Initial width: 96, current width: 150, distance: 96
# [0, 64, 150, 120] Initial width: 96, current width: 150, distance: 96
# [2, 65, 147, 118] Initial width: 96, current width: 147, distance: 96
# [3, 65, 146, 118] Initial width: 96, current width: 146, distance: 96
# [3, 63, 147, 119] Initial width: 96, current width: 147, distance: 96
# [1, 64, 150, 119] Initial width: 96, current width: 150, distance: 96
# [1, 65, 147, 117] Initial width: 96, current width: 147, distance: 96
# [2, 65, 149, 117] Initial width: 96, current width: 149, distance: 96
# [0, 65, 151, 118] Initial width: 96, current width: 151, distance: 96
# [-2, 64, 153, 121] Initial width: 96, current width: 153, distance: 96
# [0, 62, 152, 121] Initial width: 96, current width: 152, distance: 96
# [-2, 64, 154, 119] Initial width: 96, current width: 154, distance: 96
# [-3, 64, 154, 120] Initial width: 96, current width: 154, distance: 96
# [0, 63, 148, 121] Initial width: 96, current width: 148, distance: 96
# [2, 62, 144, 123] Initial width: 96, current width: 144, distance: 96
# [2, 64, 146, 119] Initial width: 96, current width: 146, distance: 96
# [1, 63, 145, 121] Initial width: 96, current width: 145, distance: 96
# [1, 64, 145, 120] Initial width: 96, current width: 145, distance: 96
# [1, 63, 148, 121] Initial width: 96, current width: 148, distance: 96
# [-2, 64, 148, 120] Initial width: 96, current width: 148, distance: 96
# [-2, 63, 152, 121] Initial width: 96, current width: 152, distance: 96
# [-1, 65, 153, 118] Initial width: 96, current width: 153, distance: 96
# [-3, 62, 154, 122] Initial width: 96, current width: 154, distance: 96
# [-3, 63, 156, 121] Initial width: 96, current width: 156, distance: 96
# [-5, 63, 159, 121] Initial width: 96, current width: 159, distance: 96
# [-6, 63, 159, 121] Initial width: 96, current width: 159, distance: 96
# [-2, 63, 153, 124] Initial width: 96, current width: 153, distance: 96
# [-3, 65, 157, 117] Initial width: 96, current width: 157, distance: 96
# [-5, 65, 160, 120] Initial width: 96, current width: 160, distance: 96
# [-7, 64, 162, 119] Initial width: 96, current width: 162, distance: 96
# [-4, 64, 156, 120] Initial width: 96, current width: 156, distance: 96
# [-7, 64, 160, 120] Initial width: 96, current width: 160, distance: 96
# [-9, 63, 163, 121] Initial width: 96, current width: 163, distance: 96
# [-10, 64, 162, 122] Initial width: 96, current width: 162, distance: 96
# [-9, 62, 162, 124] Initial width: 96, current width: 162, distance: 96
# [-9, 62, 163, 124] Initial width: 96, current width: 163, distance: 96
# [-4, 61, 156, 125] Initial width: 96, current width: 156, distance: 96
# [-9, 64, 164, 119] Initial width: 96, current width: 164, distance: 96
# [-9, 61, 162, 123] Initial width: 96, current width: 162, distance: 96
# [-7, 62, 159, 123] Initial width: 96, current width: 159, distance: 96
# [-8, 62, 162, 123] Initial width: 96, current width: 162, distance: 96
# [-7, 63, 160, 122] Initial width: 96, current width: 160, distance: 96
# [-4, 60, 154, 124] Initial width: 96, current width: 154, distance: 96
# [-2, 64, 155, 122] Initial width: 96, current width: 155, distance: 96
# [-4, 62, 156, 122] Initial width: 96, current width: 156, distance: 96
# [-4, 62, 161, 123] Initial width: 96, current width: 161, distance: 96
# [-1, 62, 155, 124] Initial width: 96, current width: 155, distance: 96
# [-1, 61, 153, 125] Initial width: 96, current width: 153, distance: 96
# [0, 61, 151, 125] Initial width: 96, current width: 151, distance: 96
# [-3, 62, 158, 124] Initial width: 96, current width: 158, distance: 96
# [-10, 57, 176, 133] Initial width: 96, current width: 176, distance: 96
# [-3, 62, 157, 122] Initial width: 96, current width: 157, distance: 96
# [-2, 63, 154, 120] Initial width: 96, current width: 154, distance: 96
# [-3, 62, 154, 123] Initial width: 96, current width: 154, distance: 96
# [-10, 59, 172, 131] Initial width: 96, current width: 172, distance: 96
# [-1, 63, 153, 121] Initial width: 96, current width: 153, distance: 96
# [-2, 61, 157, 121] Initial width: 96, current width: 157, distance: 96
# [-1, 63, 155, 121] Initial width: 96, current width: 155, distance: 96
# [-1, 62, 157, 123] Initial width: 96, current width: 157, distance: 96
# [-2, 63, 156, 120] Initial width: 96, current width: 156, distance: 96
# [-2, 62, 156, 120] Initial width: 96, current width: 156, distance: 96
# [-3, 62, 156, 121] Initial width: 96, current width: 156, distance: 96
# [-5, 62, 161, 122] Initial width: 96, current width: 161, distance: 96
# [-5, 64, 161, 120] Initial width: 96, current width: 161, distance: 96
# [-5, 63, 161, 119] Initial width: 96, current width: 161, distance: 96
# [-5, 63, 158, 120] Initial width: 96, current width: 158, distance: 96
# [-5, 62, 161, 120] Initial width: 96, current width: 161, distance: 96
# [-3, 63, 159, 121] Initial width: 96, current width: 159, distance: 96
# [-4, 64, 161, 120] Initial width: 96, current width: 161, distance: 96
# [-4, 61, 158, 124] Initial width: 96, current width: 158, distance: 96
# [-5, 63, 162, 119] Initial width: 96, current width: 162, distance: 96
# [-5, 64, 161, 120] Initial width: 96, current width: 161, distance: 96
# [-4, 63, 161, 119] Initial width: 96, current width: 161, distance: 96
# [-4, 63, 161, 121] Initial width: 96, current width: 161, distance: 96
# [-5, 63, 161, 119] Initial width: 96, current width: 161, distance: 96
# [-3, 63, 159, 118] Initial width: 96, current width: 159, distance: 96
# [-4, 62, 162, 119] Initial width: 96, current width: 162, distance: 96
# [-2, 63, 162, 119] Initial width: 96, current width: 162, distance: 96
# [-3, 61, 158, 123] Initial width: 96, current width: 158, distance: 96
# [-3, 62, 161, 122] Initial width: 96, current width: 161, distance: 96
# [-11, 57, 179, 134] Initial width: 96, current width: 179, distance: 96
# [-4, 63, 161, 120] Initial width: 96, current width: 161, distance: 96
# [-11, 57, 177, 134] Initial width: 96, current width: 177, distance: 96
# [-10, 56, 177, 137] Initial width: 96, current width: 177, distance: 96
# [-10, 55, 173, 138] Initial width: 96, current width: 173, distance: 96
# [-10, 57, 174, 133] Initial width: 96, current width: 174, distance: 96
# [-2, 63, 156, 118] Initial width: 96, current width: 156, distance: 96
# [-11, 58, 177, 133] Initial width: 96, current width: 177, distance: 96
# [-8, 58, 171, 131] Initial width: 96, current width: 171, distance: 96
# [-11, 58, 181, 131] Initial width: 96, current width: 181, distance: 96
# [-3, 60, 154, 120] Initial width: 96, current width: 154, distance: 96
# [-5, 62, 160, 121] Initial width: 96, current width: 160, distance: 96
# [-8, 58, 167, 134] Initial width: 96, current width: 167, distance: 96
# [-9, 57, 175, 136] Initial width: 96, current width: 175, distance: 96
# [-7, 58, 171, 131] Initial width: 96, current width: 171, distance: 96
# [-8, 56, 171, 136] Initial width: 96, current width: 171, distance: 96
# [-9, 59, 170, 130] Initial width: 96, current width: 170, distance: 96
# [-7, 65, 162, 116] Initial width: 96, current width: 162, distance: 96
# [-10, 56, 172, 136] Initial width: 96, current width: 172, distance: 96
# [-9, 56, 174, 137] Initial width: 96, current width: 174, distance: 96
# [-9, 56, 172, 137] Initial width: 96, current width: 172, distance: 96
# [-9, 57, 173, 136] Initial width: 96, current width: 173, distance: 96
# [-6, 62, 158, 122] Initial width: 96, current width: 158, distance: 96
# [-2, 63, 157, 122] Initial width: 96, current width: 157, distance: 96
# [-7, 62, 162, 122] Initial width: 96, current width: 162, distance: 96
# [-7, 63, 163, 121] Initial width: 96, current width: 163, distance: 96
# [-6, 62, 158, 121] Initial width: 96, current width: 158, distance: 96
# [-3, 63, 159, 119] Initial width: 96, current width: 159, distance: 96
# [-5, 62, 160, 123] Initial width: 96, current width: 160, distance: 96
# [-5, 61, 157, 125] Initial width: 96, current width: 157, distance: 96
# [-7, 62, 160, 122] Initial width: 96, current width: 160, distance: 96
# [-5, 62, 157, 122] Initial width: 96, current width: 157, distance: 96
# [-4, 62, 156, 121] Initial width: 96, current width: 156, distance: 96
# [-4, 62, 156, 122] Initial width: 96, current width: 156, distance: 96
# [-4, 63, 154, 122] Initial width: 96, current width: 154, distance: 96
# [-6, 63, 156, 120] Initial width: 96, current width: 156, distance: 96
# [-5, 60, 154, 125] Initial width: 96, current width: 154, distance: 96
# [-2, 61, 151, 123] Initial width: 96, current width: 151, distance: 96
# [-6, 62, 156, 121] Initial width: 96, current width: 156, distance: 96
# [-4, 64, 157, 119] Initial width: 96, current width: 157, distance: 96
# [-4, 61, 155, 121] Initial width: 96, current width: 155, distance: 96
# [-9, 57, 170, 134] Initial width: 96, current width: 170, distance: 96
# [-9, 56, 169, 138] Initial width: 96, current width: 169, distance: 96
# [-4, 62, 157, 120] Initial width: 96, current width: 157, distance: 96
# [-2, 61, 153, 123] Initial width: 96, current width: 153, distance: 96
# [-9, 54, 172, 140] Initial width: 96, current width: 172, distance: 96
# [-9, 55, 170, 137] Initial width: 96, current width: 170, distance: 96
# [-8, 56, 169, 138] Initial width: 96, current width: 169, distance: 96
# [-4, 61, 154, 121] Initial width: 96, current width: 154, distance: 96
# [-8, 54, 171, 141] Initial width: 96, current width: 171, distance: 96
# [-4, 63, 156, 120] Initial width: 96, current width: 156, distance: 96
# [-3, 63, 154, 120] Initial width: 96, current width: 154, distance: 96
# [-3, 63, 156, 119] Initial width: 96, current width: 156, distance: 96
# [-8, 55, 171, 140] Initial width: 96, current width: 171, distance: 96
# [-10, 52, 170, 143] Initial width: 96, current width: 170, distance: 96
# [-11, 52, 176, 144] Initial width: 96, current width: 176, distance: 96
# [-9, 49, 174, 147] Initial width: 96, current width: 174, distance: 96
# [-9, 50, 174, 147] Initial width: 96, current width: 174, distance: 96
# [-9, 53, 169, 141] Initial width: 96, current width: 169, distance: 96
# [-8, 55, 166, 137] Initial width: 96, current width: 166, distance: 96
# [-8, 54, 168, 140] Initial width: 96, current width: 168, distance: 96
# [-6, 54, 163, 140] Initial width: 96, current width: 163, distance: 96
# [-10, 55, 170, 137] Initial width: 96, current width: 170, distance: 96
# [-8, 56, 162, 135] Initial width: 96, current width: 162, distance: 96
# [-8, 56, 162, 136] Initial width: 96, current width: 162, distance: 96
# [-4, 55, 185, 134] Initial width: 96, current width: 185, distance: 96
# [-9, 55, 164, 137] Initial width: 96, current width: 164, distance: 96
# [-7, 55, 167, 138] Initial width: 96, current width: 167, distance: 96
# [-9, 55, 167, 137] Initial width: 96, current width: 167, distance: 96
# [-10, 54, 170, 140] Initial width: 96, current width: 170, distance: 96
# [-10, 52, 171, 143] Initial width: 96, current width: 171, distance: 96
# [-10, 51, 165, 145] Initial width: 96, current width: 165, distance: 96
# [-10, 52, 166, 144] Initial width: 96, current width: 166, distance: 96
# [-12, 54, 168, 140] Initial width: 96, current width: 168, distance: 96
# [-10, 51, 169, 143] Initial width: 96, current width: 169, distance: 96
# [-8, 51, 167, 143] Initial width: 96, current width: 167, distance: 96
# [-11, 48, 170, 150] Initial width: 96, current width: 170, distance: 96
# [-10, 49, 173, 147] Initial width: 96, current width: 173, distance: 96
# [-8, 50, 167, 147] Initial width: 96, current width: 167, distance: 96
# [-10, 48, 170, 150] Initial width: 96, current width: 170, distance: 96
# [-10, 50, 173, 145] Initial width: 96, current width: 173, distance: 96
# [-9, 50, 169, 145] Initial width: 96, current width: 169, distance: 96
# [-8, 51, 171, 144] Initial width: 96, current width: 171, distance: 96
# [-9, 50, 167, 146] Initial width: 96, current width: 167, distance: 96
# [-10, 49, 174, 147] Initial width: 96, current width: 174, distance: 96
# [-10, 51, 170, 143] Initial width: 96, current width: 170, distance: 96
# [-9, 51, 168, 144] Initial width: 96, current width: 168, distance: 96
# [-9, 50, 167, 148] Initial width: 96, current width: 167, distance: 96
# [-10, 50, 166, 146] Initial width: 96, current width: 166, distance: 96
# [-10, 52, 167, 142] Initial width: 96, current width: 167, distance: 96
# [-11, 49, 166, 147] Initial width: 96, current width: 166, distance: 96
# [-10, 50, 167, 145] Initial width: 96, current width: 167, distance: 96
# [-11, 50, 166, 145] Initial width: 96, current width: 166, distance: 96
# [-10, 52, 167, 144] Initial width: 96, current width: 167, distance: 96
# [-10, 49, 166, 148] Initial width: 96, current width: 166, distance: 96
# [-10, 49, 166, 148] Initial width: 96, current width: 166, distance: 96
# [-11, 49, 168, 148] Initial width: 96, current width: 168, distance: 96
# [-10, 49, 172, 148] Initial width: 96, current width: 172, distance: 96
# [-11, 49, 167, 148] Initial width: 96, current width: 167, distance: 96
# [-12, 48, 171, 150] Initial width: 96, current width: 171, distance: 96
# [-11, 49, 165, 147] Initial width: 96, current width: 165, distance: 96
# [-11, 51, 164, 143] Initial width: 96, current width: 164, distance: 96
# [-11, 49, 164, 149] Initial width: 96, current width: 164, distance: 96
# [-10, 50, 165, 146] Initial width: 96, current width: 165, distance: 96
# [-13, 50, 168, 146] Initial width: 96, current width: 168, distance: 96
# [-13, 49, 171, 147] Initial width: 96, current width: 171, distance: 96
# [-11, 48, 157, 150] Initial width: 96, current width: 157, distance: 96
# [-12, 49, 169, 147] Initial width: 96, current width: 169, distance: 96
# [-12, 48, 168, 150] Initial width: 96, current width: 168, distance: 96
# [-12, 49, 166, 148] Initial width: 96, current width: 166, distance: 96
# [-11, 46, 166, 153] Initial width: 96, current width: 166, distance: 96
# [-13, 48, 168, 149] Initial width: 96, current width: 168, distance: 96
# [-10, 47, 164, 151] Initial width: 96, current width: 164, distance: 96
# [-9, 48, 164, 152] Initial width: 96, current width: 164, distance: 96
# [-11, 49, 165, 149] Initial width: 96, current width: 165, distance: 96
# [-10, 46, 167, 155] Initial width: 96, current width: 167, distance: 96
# [-11, 49, 167, 150] Initial width: 96, current width: 167, distance: 96
# [-11, 48, 168, 150] Initial width: 96, current width: 168, distance: 96
# [-10, 46, 165, 155] Initial width: 96, current width: 165, distance: 96
# [-10, 49, 164, 149] Initial width: 96, current width: 164, distance: 96
# [-8, 45, 163, 158] Initial width: 96, current width: 163, distance: 96
# [-7, 43, 165, 162] Initial width: 96, current width: 165, distance: 96
# [-10, 48, 165, 150] Initial width: 96, current width: 165, distance: 96
# [-10, 46, 168, 155] Initial width: 96, current width: 168, distance: 96
# [-10, 48, 166, 151] Initial width: 96, current width: 166, distance: 96
# [-10, 44, 167, 157] Initial width: 96, current width: 167, distance: 96
# [-12, 49, 172, 171] Initial width: 96, current width: 172, distance: 96
# [-9, 43, 166, 161] Initial width: 96, current width: 166, distance: 96

# %%
from google.colab import files
files.download(output_name)
