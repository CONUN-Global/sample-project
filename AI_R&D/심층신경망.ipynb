# %%
#패션 MNIST : 10개 클래스, 28*28 흑백, 60000개
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

print(train_input.shape, train_target.shape)

train_scaled = train_input / 255.0

train_scaled = train_scaled.reshape(-1, 28*28)

#keras model create
from sklearn.model_selection import train_test_split
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)
print(train_scaled.shape, train_target.shape)

print(val_scaled.shape, val_target.shape)

model = keras.Sequential()
model.add(keras.layers.Dense(100, activation='sigmoid', input_shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax'))

model.summary()


model = keras.Sequential()
#모델안에 전처리를 할 수 있는 함수, 유지보수하기 편하게 함
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

model.summary()


#모델설정
#이진분류:loss='binary_crossentroy'
#다중분류:loss='categorical_crossentropy'
#다중분류이고, target 값이 정수일때는 loss='sparse_categorical_crossentropy'
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')

print(train_target[:10])

model.fit(train_scaled, train_target, epochs=5) # 훈련

model.evaluate(val_scaled, val_target) # 평가


#optimizer
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics='accuracy')

sgd = keras.optimizers.SGD()
model.compile(optimizer=sgd, loss='sparse_categorical_crossentropy', metrics='accuracy')

sgd = keras.optimizers.SGD(learning_rate=0.1)
sgd = keras.optimizers.SGD(momentum=0.9, nesterov=True)

model = keras.Sequential()
#모델안에 전처리를 할 수 있는 함수, 유지보수하기 편하게 함
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

print(train_target[:10])

model.fit(train_scaled, train_target, epochs=5) # 훈련

model.evaluate(val_scaled, val_target) # 평가
# Out:
# (60000, 28, 28) (60000,)
# (48000, 784) (48000,)
# (12000, 784) (12000,)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               78500
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________
# [7 3 5 8 6 9 3 3 9 9]
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_2_input'), name='flatten_2_input', description="created by layer 'flatten_2_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_2_input'), name='flatten_2_input', description="created by layer 'flatten_2_input'"), but it was called on an input with incompatible shape (32, 784).
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.6675 - accuracy: 0.7680
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4009 - accuracy: 0.8557
# Epoch 3/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3583 - accuracy: 0.8721
# Epoch 4/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3380 - accuracy: 0.8805
# Epoch 5/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3183 - accuracy: 0.8854
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_2_input'), name='flatten_2_input', description="created by layer 'flatten_2_input'"), but it was called on an input with incompatible shape (32, 784).
# 375/375 [==============================] - 1s 1ms/step - loss: 0.3684 - accuracy: 0.8763
# [7 3 5 8 6 9 3 3 9 9]
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_3_input'), name='flatten_3_input', description="created by layer 'flatten_3_input'"), but it was called on an input with incompatible shape (32, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_3_input'), name='flatten_3_input', description="created by layer 'flatten_3_input'"), but it was called on an input with incompatible shape (32, 784).
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.6830 - accuracy: 0.7646
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4059 - accuracy: 0.8551
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3597 - accuracy: 0.8699
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3360 - accuracy: 0.8790
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3141 - accuracy: 0.8864
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='flatten_3_input'), name='flatten_3_input', description="created by layer 'flatten_3_input'"), but it was called on an input with incompatible shape (32, 784).
# 375/375 [==============================] - 1s 1ms/step - loss: 0.3639 - accuracy: 0.8686
# [0.3638940155506134, 0.8685833215713501]
